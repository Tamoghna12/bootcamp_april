# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data import

# %%
df=pd.read_csv('/kaggle/input/bootcampsales/sales_data_sample.csv',encoding='latin')
df

# %% [markdown]
# # Numerical Inspection / Investigation of the data

# %%
# Show all columns
pd.set_option('display.max_columns', None)
df

# %%
df_cols = df.columns

# %%
df.dtypes

# %%
df.info()

# %%
df.head()

# %%
df.loc[:, ['YEAR_ID']] = df['YEAR_ID'].astype('category')

# %%
df.info()

# %% [markdown]
# # Identifying null values

# %%
df.isnull().sum()

# %%
df_cols

# %%
df_1=df[['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
       'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
       'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
       'ADDRESSLINE1', 'CITY', 'POSTALCODE',
       'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
       'DEALSIZE']]

# %%
df_1.isnull().sum()

# %%
df.shape

# %%
df_1.TERRITORY.unique()

# %% [markdown]
# # Visual Exploration

# %%
#df_region=df[['COUNTRY','TERRITORY']]
#df_region.groupby('COUNTRY')['TERRITORY'].mode()

# %%
df_1.head()

# %%
df_1.STATUS.unique()

# %% [markdown]
# # Histogram using Seaborn

# %%
# Plot histograms for multiple columns on the same axis

#
sns.histplot(data=df_1, x='STATUS', color='red', label="Order Status", kde=True)
# Add legend
plt.legend()

# Show plot
plt.show()

# %%
sns.histplot(data=df_1, x='QUANTITYORDERED', color='skyblue', label="Order Qty", kde=True)
# Add legend
plt.legend()

# Show plot
plt.show()

# %%
sns.histplot(data=df_1, x='TERRITORY', color='green', label="Location", kde=True)
# Add legend
plt.legend()

# Show plot
plt.show()

# %%
df_1.iloc[:,df_1['YEAR_ID']]=df_1['YEAR_ID'].astype('category')

# %%
df_1.iloc[:,df_1['YEAR_ID']]=pd.to_datetime(df['YEAR_ID'], format='%Y')

# %%
df_1.info()

# %%
# Create a grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Plot histograms on separate subplots
sns.histplot(data=df_1, x="STATUS", kde=True, color="skyblue", ax=axs[0, 0])
sns.histplot(data=df_1, x="QUANTITYORDERED", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df_1, x="YEAR_ID", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df_1, x="TERRITORY", kde=True, color="teal", ax=axs[1, 1])

#labels
axs[0,0].set_xlabel('Status')
axs[0,0].set_ylabel('Count')
axs[0,0].tick_params(axis='x',rotation=45)

axs[1,0].set_xlabel('Year')
axs[1,0].set_ylabel('Count')
axs[1,0].tick_params(axis='x',rotation=45)

# Show plot
plt.show()

# %%
df=pd.read_csv('/kaggle/input/bootcampsales/sales_data_sample.csv',encoding='latin')
df.head()

# %%
df.isnull().sum()

# %%
df_value=pd.DataFrame(df.value_counts())
df_value

# %%
df

# %%
df['TERRITORY']=df['TERRITORY'].replace('Japan','APAC')

# %%
df['TERRITORY'].hist()

# %%
df.isnull().sum()

# %%
df['ADDRESSLINE2'].hist()

# %%
df_null=df[df['STATE'].isnull()]
df_null

# %%
df.isnull().sum()

# %%
df_null=df.columns[df.isna().any()].tolist()
df_with_null=df[df_null]

# %%
df_with_null

# %%
df.head()

# %%
df_1.YEAR_ID.info()

# %% [markdown]
# # Row operation and extractions

# %%
status=['USA']

# %%
status_filtered = df_1[df_1['COUNTRY'].isin(status)]

# %%
status_filtered.COUNTRY.unique()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,7))
sns.lineplot(x='TERRITORY',y='QUANTITYORDERED', data=df)
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Sales over the years")
plt.show();

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='YEAR_ID',y='SALES',hue='TERRITORY', data=df)
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Sales over the years")
plt.show();

# %%
#Line plot using matplotlib

plt.figure(figsize=(10,7))
plt.plot(df['YEAR_ID'],df['SALES'])
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Sales over the years")
plt.show()

# %%
pivot_table_sales = pd.pivot_table(
    data=df,
    values='SALES',
    index='YEAR_ID',
    aggfunc='sum'
)
pivot_table_yr_sales = pivot_table_sales.reset_index()

# %%
pivot_table_yr_sales

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='YEAR_ID',y='SALES', data=pivot_table_yr_sales)
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Sales over the years")
plt.show();

# %%
df.columns

# %%
pivot_table_status = df.pivot_table(
    index='DEALSIZE',
    columns= ['TERRITORY','YEAR_ID'],
    values='QUANTITYORDERED',
    aggfunc='sum'
)

# %%
pivot_table_status_1 = pivot_table_status.reset_index()

# %%
pivot_table_status_1.plot(kind='bar', figsize=(10,6),stacked=True)
plt.xlabel('DealSize', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.title("Total order per region and dealsize", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
pivot_table_status_year = df.pivot_table(
    index='DEALSIZE',
    columns= ['YEAR_ID'],
    values='SALES',
    aggfunc='sum'
)
pv_t_yr_status=pivot_table_status_year.reset_index()

# %%
pv_t_yr_status

# %%
pv_t_yr_status.plot(kind='bar', figsize=(10,6))
plt.xlabel('DealSize', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.title("Total Sales per year and dealsize", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
pv_t_yr_status.plot(kind='line', figsize=(10,6))
plt.xlabel('DealSize', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.title("Total order per region and dealsize", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
pivot_table_terr = pd.pivot_table(
    data=df,
    values='QUANTITYORDERED',
    index=['TERRITORY'], 
    aggfunc='sum'
)

# %%
pivot_table_terr.plot(kind='bar', figsize=(10,6))
plt.xlabel('Region', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.title("Total order per region", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
pivot_table_terr.plot(kind='line', figsize=(10,6))
plt.xlabel('Region')
plt.ylabel('Total Orders')
plt.title("Total order per region")
plt.show()

# %%
pivot_table_terr

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,7))
sns.lineplot(x='TERRITORY',y='QUANTITYORDERED', data=df)
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Sales over the years")
plt.show();

# %%
pivot_table_territory = pd.pivot_table(
    data=df,
    values='SALES',
    index='TERRITORY',
    aggfunc='sum'
)

# %%
pivot_table_territory

# %%
pivot_table_territory_avg = pd.pivot_table(
    data=df,
    values='SALES',
    index='TERRITORY',
    aggfunc='mean'
)
pivot_table_territory_avg

# %%
#scatter plot using seaborn 
df.columns

# %%
df.MSRP

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,7))
sns.scatterplot(x='SALES',y='QUANTITYORDERED',hue='PRODUCTLINE',data=df, palette='viridis')
plt.xlabel("Sales")
plt.ylabel("QtyOrdered")
plt.title("Sales over quantity in different dealsize")
plt.show();

# %%
pivot_table_status.plot(kind='line', figsize=(10,6))
plt.xlabel('DealSize', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.title("Total order per region and dealsize", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
pivot_table_territory_avg = pd.pivot_table(
    data=df,
    values='SALES',
    index='TERRITORY',
    aggfunc='mean'
)
pivot_table_territory_avg

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,7))
sns.scatterplot(x='SALES',y='MSRP',hue='PRODUCTLINE',data=df, palette='Spectral')
plt.xlabel("Sales")
plt.ylabel("QtyOrdered")
plt.title("Sales over quantity in different MSRP")
plt.show();

# %%
pivot_table_year_month = pd.pivot_table(
    data=df,
    values='SALES',
    index=['TERRITORY'],
    columns=['YEAR_ID','MONTH_ID'],
    aggfunc='sum'
)
pivot_table_year_month

# %%
df[['MONTH_ID','TERRITORY','YEAR_ID','SALES']].head()

# %%
#Group by month
grouped_terr=pd.DataFrame(df.groupby(['TERRITORY','MONTH_ID','YEAR_ID',])['SALES'].sum())

# %%
grouped_terr

# %%
grouped_terr.columns

# %%
df_2004= df[df['YEAR_ID']==2004]

# %%
df_2004_group=pd.DataFrame(df_2004.groupby(['TERRITORY','MONTH_ID','YEAR_ID',])['SALES'].sum())
df_2004_group.reset_index()

# %%
pivot_2004 = pd.pivot_table(
    data=df_2004,
    values='SALES',
    index=['MONTH_ID'],
    columns=['TERRITORY'],
    aggfunc='sum'
)
pivot_2004

# %%
df.columns

# %%
pivot_2004.columns

# %%
x=df['TERRITORY']
y=df['SALES']
fig,ax=plt.subplots()
ax.bar(x,y)
#plt.bar(x,y)
ax.set_ylim(4000,10000)
plt.show()

# %%
df_2003= df[df['YEAR_ID']==2003]
pivot_2003 = pd.pivot_table(
    data=df_2003,
    values='SALES',
    index='MONTH_ID',
    columns='TERRITORY',
    aggfunc='sum'
)
pivot_2003

# %%
df_2004= df[df['YEAR_ID']==2004]
pivot_2004 = pd.pivot_table(data=df_2004,values='SALES',index=['DEALSIZE'],columns='TERRITORY',aggfunc=['max','min'])
pivot_2004.plot(kind='bar', figsize=(10,6), stacked=True)
plt.xlabel('Deal Size', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.title("Total order per region", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
df_2005= df[df['YEAR_ID']==2005]
pivot_2005 = pd.pivot_table(
    data=df_2005,
    values='SALES',
    index='MONTH_ID',
    columns='TERRITORY',
    aggfunc='sum'
)
pivot_2005

# %%
pivot_2004.reset_index().columns

# %%
df_2004

# %%
sales_per_year=df.groupby(['YEAR_ID','TERRITORY']).SALES.sum().reset_index(name='SALES')
pivot_table_yearwise = sales_per_year.pivot(index='YEAR_ID',columns='TERRITORY', values='SALES')


# Set up subplots
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(15, 10))
axes = axes.flatten()

# Plot data
for i, year in enumerate(pivot_table_yearwise.index):
    ax = axes[i]
    ax.bar(pivot_table_yearwise.columns, pivot_table_yearwise.loc[year])
    ax.set_title('Title')
    ax.set_xlabel('TERRITORY')
    ax.set_ylabel('SALES')

# Adjust layout
fig.tight_layout()
plt.show()

# %%
pivot_table_yearwise.plot(kind='bar')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
pivot_2004.reset_index().plot(kind='bar', figsize=(20,6), stacked=True, ax=axes[1])
ax.set_xlabel('Month', fontsize=5)
ax.set_ylabel('Total sales', fontsize=5)
ax.set_title("Total sales per month per region in 2004", fontsize=8)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')



pivot_2003.reset_index().plot(kind='bar', figsize=(20,6), stacked=True, ax=axes[0])
ax.set_xlabel('Month', fontsize=5)
ax.set_ylabel('Total sales', fontsize=5)
ax.set_title("Total sales per month per region in 2003", fontsize=8)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.savefig("2003_2004")
plt.show()

# %%
pivot_2004.plot(kind='bar', figsize=(10,6), stacked=True)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total sales', fontsize=12)
plt.title("Total sales per month per region in 2004", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
pivot_2004.plot(kind='line', figsize=(10,6))
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total sales', fontsize=12)
plt.title("Total sales per month per region in 2004", fontsize=15)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Statistics
#
# Statistics is a branch of mathematics that deals with the collection, analysis, interpretation, presentation, and organization of data. It involves the use of mathematical techniques to summarize and describe the characteristics of a dataset.
#
# There are two main types of statistics:
# - Descriptive Statistics and
# - Inferential Statistics.
#
# ## Descriptive Statistics: This type of statistics involves summarizing and describing the basic features of a dataset, such as the mean, median, mode, range, variance, and standard deviation.
# ## Inferential Statistics: This type of statistics involves using data from a sample to make inferences about a larger population or universe.

# %%
df.describe() # Descriptive Statistics: This type of statistics involves summarizing and describing the basic features of a dataset, such as the mean, median, mode, range, variance, and standard deviation.

# %% [markdown]
# # Inter Quartile Range
# # Q1, Q2, Q3
# # Outlier

# %%
# Q1 or the first quartile

q1 = df['QUANTITYORDERED'].quantile(0.25) 
q2 = df['QUANTITYORDERED'].quantile(0.50)
q3 = df['QUANTITYORDERED'].quantile(0.75)

# %%
q1

# %%
q2

# %%
q3

# %%
IQR = q3-q1
IQR

# %%
#Lower threshold

lower_bound = q1 - 1.5*IQR

#Higher threshold

upper_bound = q3 + 1.5*IQR

# %%
lower_bound

# %%
upper_bound

# %%
outlier = df[(df['QUANTITYORDERED'] < lower_bound) | (df['QUANTITYORDERED'] > upper_bound)]

outlier

# %%
df['QUANTITYORDERED'].hist()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['QUANTITYORDERED'],kde=True, bins=40)
plt.show()

# %%
pip list
